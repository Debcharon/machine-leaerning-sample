# %%
import matplotlib. pyplot as plt

jan_sales = [3010, 4029, 5021, 3056]
sales = [7125, 12753, 13143, 8635]
#plt.rcParams['font.sans-serif'] = ['SimHei']
#plt.rcParams['axes.unicode_minus'] = False
x = ['Apple','Banana','Pear','Kiwi']
# TODO:x为横坐标,jan_sales为纵坐标,折线为绿色,线宽为5

plt.bar(range(4), sales, 0.4, color='b', alpha = 0.8)
# 添加轴标签
plt.ylabel('Saleing')
# 添加标题
plt.title('Fruit sales in 2018')
# 添加刻度标签
plt.xticks(range(4),['Apple','Banana','Pear','Kiwi'])
# 设置Y轴的刻度范围
plt.ylim([2000, 15000])
# 为每个条形图添加数值标签
for x, y in enumerate (sales):
    plt.text(x, y+100, '%s' %y, ha='center')
# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# 数据个数
n = 50
# 均值为0,方差为1的随机数
x = np.random.normal(0, 1, n)
y = np.random.normal(0, 1, n)
# 计算颜色值
color = np.arctan2(y, x)
# TODO:绘制散点图:x为横坐标,y为纵坐标;s为size=75,按每个点的坐标绘制:颜色为color,透明度为0.5
# 绘制散点图:x为横坐标,y为纵坐标;s为size=75,按每个点的坐标绘制:颜色为color,透明度为0.5
plt.scatter(x, y, s=75, c=color, alpha=0.5)

# 设置坐标轴范围
plt.xlim((-1.5, 1.5))
plt.ylim((-1.5, 1.5))
# 不显示坐标轴的值
plt.xticks(([-1, 0, 1, 2, 3, 4]))
plt.yticks(([-1, 0,1, 2, 3, 4]))
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [7125, 12753, 13143, 8635]
#plt.rcParams['font.sans-serif'] = ['SimHei']
#plt.rcParams['axes.unicode_minus'] = False
#TODO:x为4种水果,y为销量,柱子宽度为0.4,红色柱子,alpha是柱子的透明度为0.8
plt.bar(range(4), sales, width=0.4, color='red', alpha=0.8)

plt.ylabel('Saleing')
plt.title('Fruit sales in 2018')
plt.xticks(range(4),['Apple','Banana','Pear','Kiwi'])
plt.ylim([5000, 15000])
# 为每个条形图添加数值标签
for x, y in enumerate(sales):
    plt.text(x, y+100,'%s' %y, ha ='center')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#TODO:设置随机种子
np.random.seed(1234)

df = pd.DataFrame(np. random.rand(5, 4),
columns = ['A','B','C','D'])#先生成0-1之间的5*4维度数据,再装入4列DataFrame中
df.plot.box()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

d={"时间":pd.Series([2006,2007,2008,2009,2010]),
   "数量":pd.Series([10,200,120,150,300]),
   "大小":pd.Series([50,130,40,50,160]),
   "分类":pd.Series([1,2,0,1,2]),
   "判断":pd.Series([True,True,True,True, True])}

df=pd.DataFrame(d)
size=df['大小'].rank()
n=20
#定义一个字典,将颜色跟对应的分类进行绑定
color={0:'red', 1:'blue', 2:'orange'}
#增加color的参数,用列表解析式将data分类中的每个数据的数字映射到前面color的颜色中
plt.scatter(df['数量'],df['大小'],color=[color[i] for i in df['分类']],s=size*n,alpha=0.6)
plt.show()
